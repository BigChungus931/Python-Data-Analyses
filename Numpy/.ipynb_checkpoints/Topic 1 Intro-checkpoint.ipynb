# %% [markdown]
# # Introduction to Numpy

# %% [markdown]
# ## What is Numpy
#
# Numpy stands for Numerical Python and is the foundation of all numerical computing in Python/. <br>
# Numpy uses optimized C code. <br>
# Operating on 1 million numbers takes milliseconds not minutes.
#
# ## Importing Numpy

# %%
import numpy as np
