# %% [markdown]
# # Pandas Practice

# %%
import pandas as pd

# %%
s = pd.Series([10, 20, 30])

print(type(s))
# Out:
# <class 'pandas.Series'>

# %%
import pandas as pd
scores = pd.Series([88, 95, 72])
print(scores.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)
